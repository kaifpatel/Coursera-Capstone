# %% [markdown]
# # <p style="text-align: center;"> Using School Immunization Rates and Venue Location Data to Choose Medical Clinic Locations </p>
#
# ## <p style="text-align: center;">  Kaif Patel </p>

# %% [markdown]
# ## Introduction/Business Problem:
#
# The business problem that we have is understanding how to choose the ideal location for opening a medical clinic. The audience that would be interested in solving this problem are medical professionals and medical clinic stakeholders. As stakeholders their primary interests would be due to public health concerns as well as their return on investment. We will be using the city of Toronto as an example to understand this problem and create an ideal solution. By assessing the supply and demand of medical services we can address this problem. One method that we can use to assess the demand is by looking at the immunization rates of all nearby schools. Then in order to understand the supply of medical support we will look at existing medical clinics in the local area.
#
# <br>
#
# ## Data:
#
# The data used to solve this problem will be the Immunization Coverage for Students Data from the Toronto Open Data portal, and the Foursquare location data in order to search and count medical clinics near all Toronto schools. The immunization data has immunization rates for each individual school, as well as latitude and longitude values which we can then use to search for nearby medical clinic venues within a given radius.

# %%
# importing and installing necessary libraries

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment these 2 lines if you don't have these packages installed
#!conda install -c conda-forge geopy --yes 

import pandas as pd
import numpy as np
import folium
import matplotlib.cm as cm
import matplotlib.colors as colors
import geocoder 
from geopy.geocoders import Nominatim 
import json 
from pandas.io.json import json_normalize 
import requests
import csv


print ('imported')
# Out:
# imported

# %%
pip install geocoder
# Out:
# Requirement already satisfied: geocoder in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (1.38.1)
# Requirement already satisfied: ratelim in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (0.1.6)
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (2.22.0)
# Requirement already satisfied: future in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (0.18.2)
# Requirement already satisfied: six in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (1.13.0)
# Requirement already satisfied: click in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from geocoder) (7.0)
# Requirement already satisfied: decorator in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from ratelim->geocoder) (4.4.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (1.25.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests->geocoder) (2019.11.28)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (2.22.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests) (1.25.7)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages (from requests) (2019.11.28)
# Note: you may need to restart the kernel to use updated packages.

# %%
# downloading dataset from toronto open data portal

# !wget -O immunization-coverage-2018-2019.csv https://ckan0.cf.opendata.inter.prod-toronto.ca/download_resource/dd2f7d66-3902-478d-bde8-dcfbaef589d6?format=csv
# Out:
# --2020-02-02 04:37:47--  https://ckan0.cf.opendata.inter.prod-toronto.ca/download_resource/dd2f7d66-3902-478d-bde8-dcfbaef589d6?format=csv
# Resolving ckan0.cf.opendata.inter.prod-toronto.ca (ckan0.cf.opendata.inter.prod-toronto.ca)... 13.249.134.65, 13.249.134.19, 13.249.134.28, ...
# Connecting to ckan0.cf.opendata.inter.prod-toronto.ca (ckan0.cf.opendata.inter.prod-toronto.ca)|13.249.134.65|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/csv]
# Saving to: ‘immunization-coverage-2018-2019.csv’
#
# immunization-covera     [ <=>                ]  57.05K  --.-KB/s    in 0.02s
#
# 2020-02-02 04:37:49 (2.53 MB/s) - ‘immunization-coverage-2018-2019.csv’ saved [58417]

# %%
# reading and displaying dataset

df = pd.read_csv('immunization-coverage-2018-2019.csv')
df
# Out:
#      _id                     School Name  Enrolled population  \
# 0      1                A Y Jackson S.S.                 1027
# 1      2        Academie Alexandre-Dumas                  129
# 2      3               Adam Beck Jr P.S.                  309
# 3      4  Africentric Alternative School                   77
# 4      5                  Agincourt C.I.                 1241
# ..   ...                             ...                  ...
# 801  802              York Memorial C.I.                  876
# 802  803                 York Mills C.I.                 1200
# 803  804                   Yorkview P.S.                  256
# 804  805                  Yorkwoods P.S.                  224
# 805  806            Zion Heights Jr H.S.                  592
#
#      DTP coverage rate (%)  DTP Religious exemption rate (%)  \
# 0                     89.0                               1.1
# 1                     86.8                               1.6
# 2                     96.1                               3.6
# 3                     71.4                              20.8
# 4                     87.3                               1.0
# ..                     ...                               ...
# 801                   86.8                               2.5
# 802                   86.3                               1.3
# 803                   93.8                               2.3
# 804                   88.4                               0.9
# 805                   94.4                               1.0
#
#      MMR coverage rate (%)  MMR Religious exemption rate (%)        Lat  \
# 0                     96.5                               1.1  43.805261
# 1                     89.1                               1.6  43.762419
# 2                     95.8                               3.6  43.683152
# 3                     72.7                              20.8  43.745424
# 4                     98.1                               1.0  43.788874
# ..                     ...                               ...        ...
# 801                   96.3                               2.5  43.690279
# 802                   97.2                               1.3  43.751529
# 803                   93.0                               2.3  43.772574
# 804                   91.5                               0.9  43.750660
# 805                   96.5                               1.0  43.797915
#
#            Lng
# 0   -79.366555
# 1   -79.179765
# 2   -79.288488
# 3   -79.488261
# 4   -79.278910
# ..         ...
# 801 -79.476240
# 802 -79.373524
# 803 -79.435566
# 804 -79.513885
# 805 -79.371097
#
# [806 rows x 9 columns]

# %% [markdown]
# ## Table Information:
#
# DTP = diphtheria, tetanus, polio vaccine
# <br>
# MMR = measles, mumps, rubella vaccine

# %%
# We don't need to know the religious exemption rates for both vaccines so we can drop these columns. We will leave the enrolled population data so we can see just how much the lack of vaccinations may be affecting the population. 

df = df.drop(['_id', 'DTP Religious exemption rate (%)', 'MMR Religious exemption rate (%)'], axis=1)
df.head()
# Out:
#                       School Name  Enrolled population  DTP coverage rate (%)  \
# 0                A Y Jackson S.S.                 1027                   89.0
# 1        Academie Alexandre-Dumas                  129                   86.8
# 2               Adam Beck Jr P.S.                  309                   96.1
# 3  Africentric Alternative School                   77                   71.4
# 4                  Agincourt C.I.                 1241                   87.3
#
#    MMR coverage rate (%)        Lat        Lng
# 0                   96.5  43.805261 -79.366555
# 1                   89.1  43.762419 -79.179765
# 2                   95.8  43.683152 -79.288488
# 3                   72.7  43.745424 -79.488261
# 4                   98.1  43.788874 -79.278910

# %%
# Due to the recent resurgence of measles, we will sort by MMR coverage rate to gain a better idea for what schools have the lowest MMR immunization rates

df = df.sort_values(['MMR coverage rate (%)']).reset_index(drop=True)
df
# Out:
#                                School Name  Enrolled population  \
# 0                      St Rene Goupil C.S.                   95
# 1                          Da Vinci School                   47
# 2            Ecole elementaire Paul-Demers                   66
# 3                           Greenwood S.S.                  123
# 4              Alpha II Alternative School                   19
# ..                                     ...                  ...
# 801      South East Year Round Alternative                   27
# 802     Monsignor Fraser College - Midland                   16
# 803  Monsignor Fraser College - St. Martin                   16
# 804               Victoria Park Elementary                   92
# 805             East York Alternative S.S.                   60
#
#      DTP coverage rate (%)  MMR coverage rate (%)        Lat        Lng
# 0                     57.9                   57.9  43.819348 -79.288303
# 1                     57.4                   59.6  43.658953 -79.401910
# 2                     53.0                   60.6  43.791952 -79.367340
# 3                     61.8                   64.2  43.682839 -79.334090
# 4                     52.6                   68.4  43.659557 -79.436283
# ..                     ...                    ...        ...        ...
# 801                   92.6                  100.0  43.728101 -79.256689
# 802                   87.5                  100.0  43.801069 -79.285717
# 803                   62.5                  100.0  43.667175 -79.364426
# 804                   98.9                  100.0  43.712689 -79.298151
# 805                   90.0                  100.0  43.694991 -79.325296
#
# [806 rows x 6 columns]

# %%
# checking toronto latitude and longitude coordinates using geocoder

address = 'Toronto, ON'

geolocator = Nominatim(user_agent="to_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinates of Toronto are {}, {}.'.format(latitude, longitude))
# Out:
# The geograpical coordinates of Toronto are 43.653963, -79.387207.

# %%
# creating map of Toronto with school data
map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10.7)

# adding markers to map
for lat, lng, school, pop, mmrcov in zip(df['Lat'], df['Lng'], df['School Name'], df['Enrolled population'], df['MMR coverage rate (%)']):
    label = ("{}, Vaccination Rate (%): {}, Population: {} ").format(school, mmrcov, pop)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=4,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)

# generating map    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Figure 1. Map showing vaccination rate and population of every school in Toronto. The blue markers represent the schools.

# %%
# entering foursquare credentials

CLIENT_ID = 'MSWQU2E54PNNZER5WFZQ4P3YMHKXXESTOBXLSPUFRDASCJKI' # your Foursquare ID
CLIENT_SECRET = '5VTGKWKXGLXY4KSLLXVMEWIMQZ0BIVAEEGFL2BXXWZBRRQJI' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: MSWQU2E54PNNZER5WFZQ4P3YMHKXXESTOBXLSPUFRDASCJKI
# CLIENT_SECRET:5VTGKWKXGLXY4KSLLXVMEWIMQZ0BIVAEEGFL2BXXWZBRRQJI

# %%
# creating function to generate venue information from foursquare API

def getNearbyVenues(names, latitudes, longitudes, radius=3000, LIMIT=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?categoryId=4bf58dd8d48988d177941735&intent=browse&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['School Name', 
                  'School Lat', 
                  'School Lng', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
# generating venue data from foursquare API

names=df['School Name']
latitudes=df['Lat']
longitudes=df['Lng']

school_venues = getNearbyVenues(names, 
                                latitudes,
                                longitudes)

# %%
# saving venue information

school_venues.to_csv('school_venues.csv')

# %%
# reading venue information

school_venues = pd.read_csv('school_venues.csv')

# %%
# displaying venue information

school_venues
# Out:
#        Unnamed: 0                 School Name  School Lat  School Lng  \
# 0               0         St Rene Goupil C.S.   43.819348  -79.288303
# 1               1         St Rene Goupil C.S.   43.819348  -79.288303
# 2               2         St Rene Goupil C.S.   43.819348  -79.288303
# 3               3         St Rene Goupil C.S.   43.819348  -79.288303
# 4               4             Da Vinci School   43.658953  -79.401910
# ...           ...                         ...         ...         ...
# 12004       12004  East York Alternative S.S.   43.694991  -79.325296
# 12005       12005  East York Alternative S.S.   43.694991  -79.325296
# 12006       12006  East York Alternative S.S.   43.694991  -79.325296
# 12007       12007  East York Alternative S.S.   43.694991  -79.325296
# 12008       12008  East York Alternative S.S.   43.694991  -79.325296
#
#                                                Venue  Venue Latitude  \
# 0                         Silver Star Medical Centre       43.815107
# 1      Dr. Albert S.Y. Ng & Associates (Optometrist)       43.804021
# 2                            Dr. Norman Bethune C.I.       43.811589
# 3                 MCI The Doctor's Office (Bamburgh)       43.814874
# 4                            Totum Life Science King       43.645119
# ...                                              ...             ...
# 12004                       Appletree Medical Centre       43.713675
# 12005                    Crescent Town Health Centre       43.696474
# 12006                     German Roots in Russia PGS       43.674828
# 12007     GoodLife Fitness Toronto Danforth and Pape       43.678545
# 12008                           Nardini Naturopathic       43.677640
#
#        Venue Longitude   Venue Category
# 0           -79.294900  Doctor's Office
# 1           -79.286738  Doctor's Office
# 2           -79.319662  Doctor's Office
# 3           -79.323283  Doctor's Office
# 4           -79.395883  Doctor's Office
# ...                ...              ...
# 12004       -79.306989  Doctor's Office
# 12005       -79.293405  Doctor's Office
# 12006       -79.342977  Doctor's Office
# 12007       -79.345305  Doctor's Office
# 12008       -79.353116  Doctor's Office
#
# [12009 rows x 8 columns]

# %%
# dropping extra index column from saved file

school_venues.drop(school_venues.columns[0], axis = 1, inplace = True)

# %%
# checking venues for outliers that could be making the data dirty

school_venues.head(10)
# Out:
#            School Name  School Lat  School Lng  \
# 0  St Rene Goupil C.S.   43.819348  -79.288303
# 1  St Rene Goupil C.S.   43.819348  -79.288303
# 2  St Rene Goupil C.S.   43.819348  -79.288303
# 3  St Rene Goupil C.S.   43.819348  -79.288303
# 4      Da Vinci School   43.658953  -79.401910
# 5      Da Vinci School   43.658953  -79.401910
# 6      Da Vinci School   43.658953  -79.401910
# 7      Da Vinci School   43.658953  -79.401910
# 8      Da Vinci School   43.658953  -79.401910
# 9      Da Vinci School   43.658953  -79.401910
#
#                                            Venue  Venue Latitude  \
# 0                     Silver Star Medical Centre       43.815107
# 1  Dr. Albert S.Y. Ng & Associates (Optometrist)       43.804021
# 2                        Dr. Norman Bethune C.I.       43.811589
# 3             MCI The Doctor's Office (Bamburgh)       43.814874
# 4                        Totum Life Science King       43.645119
# 5      GoodLife Fitness Toronto 137 Yonge Street       43.651242
# 6   GoodLife Fitness Toronto Bell Trinity Centre       43.653436
# 7     GoodLife Fitness Toronto Richmond and John       43.648754
# 8         GoodLife Fitness Toronto Bloor and Bay       43.669863
# 9                         Emkiro Health Services       43.646784
#
#    Venue Longitude   Venue Category
# 0       -79.294900  Doctor's Office
# 1       -79.286738  Doctor's Office
# 2       -79.319662  Doctor's Office
# 3       -79.323283  Doctor's Office
# 4       -79.395883  Doctor's Office
# 5       -79.378068              Gym
# 6       -79.382314  Doctor's Office
# 7       -79.391940              Gym
# 8       -79.390176  Doctor's Office
# 9       -79.384264  Doctor's Office

# %%
# creating new column with frequency counts of all venues per school

school_venues['freq'] = school_venues.groupby('School Name')['School Name'].transform('count')
school_venues
# Out:
#                       School Name  School Lat  School Lng  \
# 0             St Rene Goupil C.S.   43.819348  -79.288303
# 1             St Rene Goupil C.S.   43.819348  -79.288303
# 2             St Rene Goupil C.S.   43.819348  -79.288303
# 3             St Rene Goupil C.S.   43.819348  -79.288303
# 4                 Da Vinci School   43.658953  -79.401910
# ...                           ...         ...         ...
# 12004  East York Alternative S.S.   43.694991  -79.325296
# 12005  East York Alternative S.S.   43.694991  -79.325296
# 12006  East York Alternative S.S.   43.694991  -79.325296
# 12007  East York Alternative S.S.   43.694991  -79.325296
# 12008  East York Alternative S.S.   43.694991  -79.325296
#
#                                                Venue  Venue Latitude  \
# 0                         Silver Star Medical Centre       43.815107
# 1      Dr. Albert S.Y. Ng & Associates (Optometrist)       43.804021
# 2                            Dr. Norman Bethune C.I.       43.811589
# 3                 MCI The Doctor's Office (Bamburgh)       43.814874
# 4                            Totum Life Science King       43.645119
# ...                                              ...             ...
# 12004                       Appletree Medical Centre       43.713675
# 12005                    Crescent Town Health Centre       43.696474
# 12006                     German Roots in Russia PGS       43.674828
# 12007     GoodLife Fitness Toronto Danforth and Pape       43.678545
# 12008                           Nardini Naturopathic       43.677640
#
#        Venue Longitude   Venue Category  freq
# 0           -79.294900  Doctor's Office     4
# 1           -79.286738  Doctor's Office     4
# 2           -79.319662  Doctor's Office     4
# 3           -79.323283  Doctor's Office     4
# 4           -79.395883  Doctor's Office    69
# ...                ...              ...   ...
# 12004       -79.306989  Doctor's Office    13
# 12005       -79.293405  Doctor's Office    13
# 12006       -79.342977  Doctor's Office    13
# 12007       -79.345305  Doctor's Office    13
# 12008       -79.353116  Doctor's Office    13
#
# [12009 rows x 8 columns]

# %%
# renaming dataframe

df2 = school_venues
df2
# Out:
#                       School Name  School Lat  School Lng  \
# 0             St Rene Goupil C.S.   43.819348  -79.288303
# 1             St Rene Goupil C.S.   43.819348  -79.288303
# 2             St Rene Goupil C.S.   43.819348  -79.288303
# 3             St Rene Goupil C.S.   43.819348  -79.288303
# 4                 Da Vinci School   43.658953  -79.401910
# ...                           ...         ...         ...
# 12004  East York Alternative S.S.   43.694991  -79.325296
# 12005  East York Alternative S.S.   43.694991  -79.325296
# 12006  East York Alternative S.S.   43.694991  -79.325296
# 12007  East York Alternative S.S.   43.694991  -79.325296
# 12008  East York Alternative S.S.   43.694991  -79.325296
#
#                                                Venue  Venue Latitude  \
# 0                         Silver Star Medical Centre       43.815107
# 1      Dr. Albert S.Y. Ng & Associates (Optometrist)       43.804021
# 2                            Dr. Norman Bethune C.I.       43.811589
# 3                 MCI The Doctor's Office (Bamburgh)       43.814874
# 4                            Totum Life Science King       43.645119
# ...                                              ...             ...
# 12004                       Appletree Medical Centre       43.713675
# 12005                    Crescent Town Health Centre       43.696474
# 12006                     German Roots in Russia PGS       43.674828
# 12007     GoodLife Fitness Toronto Danforth and Pape       43.678545
# 12008                           Nardini Naturopathic       43.677640
#
#        Venue Longitude   Venue Category  freq
# 0           -79.294900  Doctor's Office     4
# 1           -79.286738  Doctor's Office     4
# 2           -79.319662  Doctor's Office     4
# 3           -79.323283  Doctor's Office     4
# 4           -79.395883  Doctor's Office    69
# ...                ...              ...   ...
# 12004       -79.306989  Doctor's Office    13
# 12005       -79.293405  Doctor's Office    13
# 12006       -79.342977  Doctor's Office    13
# 12007       -79.345305  Doctor's Office    13
# 12008       -79.353116  Doctor's Office    13
#
# [12009 rows x 8 columns]

# %%
# dropping all rows with goodlife fitness

df2 = df2[~df2.Venue.str.startswith('GoodLife Fitness')]

# %%
# saving cleaned venue data

df2.to_csv('school_venues_cleaned.csv')

# %%
# reading cleaned venue data to new dataframe

df3 = pd.read_csv('school_venues_cleaned.csv')

# %%
# displaying cleaned venue data

df3
# Out:
#        Unnamed: 0                 School Name  School Lat  School Lng  \
# 0               0         St Rene Goupil C.S.   43.819348  -79.288303
# 1               1         St Rene Goupil C.S.   43.819348  -79.288303
# 2               2         St Rene Goupil C.S.   43.819348  -79.288303
# 3               3         St Rene Goupil C.S.   43.819348  -79.288303
# 4               4             Da Vinci School   43.658953  -79.401910
# ...           ...                         ...         ...         ...
# 11495       12003  East York Alternative S.S.   43.694991  -79.325296
# 11496       12004  East York Alternative S.S.   43.694991  -79.325296
# 11497       12005  East York Alternative S.S.   43.694991  -79.325296
# 11498       12006  East York Alternative S.S.   43.694991  -79.325296
# 11499       12008  East York Alternative S.S.   43.694991  -79.325296
#
#                                                Venue  Venue Latitude  \
# 0                         Silver Star Medical Centre       43.815107
# 1      Dr. Albert S.Y. Ng & Associates (Optometrist)       43.804021
# 2                            Dr. Norman Bethune C.I.       43.811589
# 3                 MCI The Doctor's Office (Bamburgh)       43.814874
# 4                            Totum Life Science King       43.645119
# ...                                              ...             ...
# 11495                Dawes Family Practice & Walk-In       43.689467
# 11496                       Appletree Medical Centre       43.713675
# 11497                    Crescent Town Health Centre       43.696474
# 11498                     German Roots in Russia PGS       43.674828
# 11499                           Nardini Naturopathic       43.677640
#
#        Venue Longitude   Venue Category  freq
# 0           -79.294900  Doctor's Office     4
# 1           -79.286738  Doctor's Office     4
# 2           -79.319662  Doctor's Office     4
# 3           -79.323283  Doctor's Office     4
# 4           -79.395883  Doctor's Office    69
# ...                ...              ...   ...
# 11495       -79.296951  Doctor's Office    13
# 11496       -79.306989  Doctor's Office    13
# 11497       -79.293405  Doctor's Office    13
# 11498       -79.342977  Doctor's Office    13
# 11499       -79.353116  Doctor's Office    13
#
# [11500 rows x 9 columns]

# %%
# dropping extra index column from saved file

df3.drop(df3.columns[0:1], axis = 1, inplace = True)

df3
# Out:
#                       School Name  School Lat  School Lng  \
# 0             St Rene Goupil C.S.   43.819348  -79.288303
# 1             St Rene Goupil C.S.   43.819348  -79.288303
# 2             St Rene Goupil C.S.   43.819348  -79.288303
# 3             St Rene Goupil C.S.   43.819348  -79.288303
# 4                 Da Vinci School   43.658953  -79.401910
# ...                           ...         ...         ...
# 11495  East York Alternative S.S.   43.694991  -79.325296
# 11496  East York Alternative S.S.   43.694991  -79.325296
# 11497  East York Alternative S.S.   43.694991  -79.325296
# 11498  East York Alternative S.S.   43.694991  -79.325296
# 11499  East York Alternative S.S.   43.694991  -79.325296
#
#                                                Venue  Venue Latitude  \
# 0                         Silver Star Medical Centre       43.815107
# 1      Dr. Albert S.Y. Ng & Associates (Optometrist)       43.804021
# 2                            Dr. Norman Bethune C.I.       43.811589
# 3                 MCI The Doctor's Office (Bamburgh)       43.814874
# 4                            Totum Life Science King       43.645119
# ...                                              ...             ...
# 11495                Dawes Family Practice & Walk-In       43.689467
# 11496                       Appletree Medical Centre       43.713675
# 11497                    Crescent Town Health Centre       43.696474
# 11498                     German Roots in Russia PGS       43.674828
# 11499                           Nardini Naturopathic       43.677640
#
#        Venue Longitude   Venue Category  freq
# 0           -79.294900  Doctor's Office     4
# 1           -79.286738  Doctor's Office     4
# 2           -79.319662  Doctor's Office     4
# 3           -79.323283  Doctor's Office     4
# 4           -79.395883  Doctor's Office    69
# ...                ...              ...   ...
# 11495       -79.296951  Doctor's Office    13
# 11496       -79.306989  Doctor's Office    13
# 11497       -79.293405  Doctor's Office    13
# 11498       -79.342977  Doctor's Office    13
# 11499       -79.353116  Doctor's Office    13
#
# [11500 rows x 8 columns]

# %%
# dropping columns to clean this dataframe so it can be merged with original dataframe

df2.drop(['School Lat', 'School Lng', 'Venue', 'Venue Latitude', 'Venue Longitude', 'Venue Category'], axis = 1, inplace = True)
df2
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/pandas/core/frame.py:4117: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                       School Name  freq
# 0             St Rene Goupil C.S.     4
# 1             St Rene Goupil C.S.     4
# 2             St Rene Goupil C.S.     4
# 3             St Rene Goupil C.S.     4
# 4                 Da Vinci School    69
# ...                           ...   ...
# 12003  East York Alternative S.S.    13
# 12004  East York Alternative S.S.    13
# 12005  East York Alternative S.S.    13
# 12006  East York Alternative S.S.    13
# 12008  East York Alternative S.S.    13
#
# [11500 rows x 2 columns]

# %%
# dropping duplicates and resetting index

df2.drop_duplicates(inplace = True)
df2.reset_index(drop = True, inplace = True)
df2
# Out:
# /home/jupyterlab/conda/envs/python/lib/python3.6/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                School Name  freq
# 0                      St Rene Goupil C.S.     4
# 1                          Da Vinci School    69
# 2            Ecole elementaire Paul-Demers    11
# 3                           Greenwood S.S.    17
# 4              Alpha II Alternative School    22
# ..                                     ...   ...
# 801      South East Year Round Alternative     4
# 802     Monsignor Fraser College - Midland    10
# 803  Monsignor Fraser College - St. Martin    67
# 804               Victoria Park Elementary    11
# 805             East York Alternative S.S.    13
#
# [806 rows x 2 columns]

# %%
# displaying original dataframe

df
# Out:
#                                School Name  Enrolled population  \
# 0                      St Rene Goupil C.S.                   95
# 1                          Da Vinci School                   47
# 2            Ecole elementaire Paul-Demers                   66
# 3                           Greenwood S.S.                  123
# 4              Alpha II Alternative School                   19
# ..                                     ...                  ...
# 801      South East Year Round Alternative                   27
# 802     Monsignor Fraser College - Midland                   16
# 803  Monsignor Fraser College - St. Martin                   16
# 804               Victoria Park Elementary                   92
# 805             East York Alternative S.S.                   60
#
#      DTP coverage rate (%)  MMR coverage rate (%)        Lat        Lng
# 0                     57.9                   57.9  43.819348 -79.288303
# 1                     57.4                   59.6  43.658953 -79.401910
# 2                     53.0                   60.6  43.791952 -79.367340
# 3                     61.8                   64.2  43.682839 -79.334090
# 4                     52.6                   68.4  43.659557 -79.436283
# ..                     ...                    ...        ...        ...
# 801                   92.6                  100.0  43.728101 -79.256689
# 802                   87.5                  100.0  43.801069 -79.285717
# 803                   62.5                  100.0  43.667175 -79.364426
# 804                   98.9                  100.0  43.712689 -79.298151
# 805                   90.0                  100.0  43.694991 -79.325296
#
# [806 rows x 6 columns]

# %%
# merging dataframes to get frequency counts of nearby clinics for each school

result = pd.merge(df,
                 df2[['School Name', 'freq']],
                 on='School Name',
                 how='left')

df = result
df
# Out:
#                                School Name  Enrolled population  \
# 0                      St Rene Goupil C.S.                   95
# 1                          Da Vinci School                   47
# 2            Ecole elementaire Paul-Demers                   66
# 3                           Greenwood S.S.                  123
# 4              Alpha II Alternative School                   19
# ..                                     ...                  ...
# 801      South East Year Round Alternative                   27
# 802     Monsignor Fraser College - Midland                   16
# 803  Monsignor Fraser College - St. Martin                   16
# 804               Victoria Park Elementary                   92
# 805             East York Alternative S.S.                   60
#
#      DTP coverage rate (%)  MMR coverage rate (%)        Lat        Lng  freq
# 0                     57.9                   57.9  43.819348 -79.288303     4
# 1                     57.4                   59.6  43.658953 -79.401910    69
# 2                     53.0                   60.6  43.791952 -79.367340    11
# 3                     61.8                   64.2  43.682839 -79.334090    17
# 4                     52.6                   68.4  43.659557 -79.436283    22
# ..                     ...                    ...        ...        ...   ...
# 801                   92.6                  100.0  43.728101 -79.256689     4
# 802                   87.5                  100.0  43.801069 -79.285717    10
# 803                   62.5                  100.0  43.667175 -79.364426    67
# 804                   98.9                  100.0  43.712689 -79.298151    11
# 805                   90.0                  100.0  43.694991 -79.325296    13
#
# [806 rows x 7 columns]

# %%
# finding average vaccination rate because some schools have really high MMR coverage but really low DTP coverage(or vice versa), we want to get an approximate idea of overall vaccination rate per school

cols = ['DTP coverage rate (%)', 'MMR coverage rate (%)']

df['Average vaccine coverage rate (%)'] = df[cols].astype(float).mean(axis=1)

df
# Out:
#                                School Name  Enrolled population  \
# 0                      St Rene Goupil C.S.                   95
# 1                          Da Vinci School                   47
# 2            Ecole elementaire Paul-Demers                   66
# 3                           Greenwood S.S.                  123
# 4              Alpha II Alternative School                   19
# ..                                     ...                  ...
# 801      South East Year Round Alternative                   27
# 802     Monsignor Fraser College - Midland                   16
# 803  Monsignor Fraser College - St. Martin                   16
# 804               Victoria Park Elementary                   92
# 805             East York Alternative S.S.                   60
#
#      DTP coverage rate (%)  MMR coverage rate (%)        Lat        Lng  freq  \
# 0                     57.9                   57.9  43.819348 -79.288303     4
# 1                     57.4                   59.6  43.658953 -79.401910    69
# 2                     53.0                   60.6  43.791952 -79.367340    11
# 3                     61.8                   64.2  43.682839 -79.334090    17
# 4                     52.6                   68.4  43.659557 -79.436283    22
# ..                     ...                    ...        ...        ...   ...
# 801                   92.6                  100.0  43.728101 -79.256689     4
# 802                   87.5                  100.0  43.801069 -79.285717    10
# 803                   62.5                  100.0  43.667175 -79.364426    67
# 804                   98.9                  100.0  43.712689 -79.298151    11
# 805                   90.0                  100.0  43.694991 -79.325296    13
#
#      Average vaccine coverage rate (%)
# 0                                57.90
# 1                                58.50
# 2                                56.80
# 3                                63.00
# 4                                60.50
# ..                                 ...
# 801                              96.30
# 802                              93.75
# 803                              81.25
# 804                              99.45
# 805                              95.00
#
# [806 rows x 8 columns]

# %%
# finding total percentage of students that are not vaccinated

df['Average vaccine noncoverage rate (%)'] = 100 - df['Average vaccine coverage rate (%)']

df
# Out:
#                                School Name  Enrolled population  \
# 0                      St Rene Goupil C.S.                   95
# 1                          Da Vinci School                   47
# 2            Ecole elementaire Paul-Demers                   66
# 3                           Greenwood S.S.                  123
# 4              Alpha II Alternative School                   19
# ..                                     ...                  ...
# 801      South East Year Round Alternative                   27
# 802     Monsignor Fraser College - Midland                   16
# 803  Monsignor Fraser College - St. Martin                   16
# 804               Victoria Park Elementary                   92
# 805             East York Alternative S.S.                   60
#
#      DTP coverage rate (%)  MMR coverage rate (%)        Lat        Lng  freq  \
# 0                     57.9                   57.9  43.819348 -79.288303     4
# 1                     57.4                   59.6  43.658953 -79.401910    69
# 2                     53.0                   60.6  43.791952 -79.367340    11
# 3                     61.8                   64.2  43.682839 -79.334090    17
# 4                     52.6                   68.4  43.659557 -79.436283    22
# ..                     ...                    ...        ...        ...   ...
# 801                   92.6                  100.0  43.728101 -79.256689     4
# 802                   87.5                  100.0  43.801069 -79.285717    10
# 803                   62.5                  100.0  43.667175 -79.364426    67
# 804                   98.9                  100.0  43.712689 -79.298151    11
# 805                   90.0                  100.0  43.694991 -79.325296    13
#
#      Average vaccine coverage rate (%)  Average vaccine noncoverage rate (%)
# 0                                57.90                                 42.10
# 1                                58.50                                 41.50
# 2                                56.80                                 43.20
# 3                                63.00                                 37.00
# 4                                60.50                                 39.50
# ..                                 ...                                   ...
# 801                              96.30                                  3.70
# 802                              93.75                                  6.25
# 803                              81.25                                 18.75
# 804                              99.45                                  0.55
# 805                              95.00                                  5.00
#
# [806 rows x 9 columns]

# %%
# changing nonvaccinated student percentage into a ratio

df['Average vaccine noncoverage ratio'] = df['Average vaccine noncoverage rate (%)']/100

df
# Out:
#                                School Name  Enrolled population  \
# 0                      St Rene Goupil C.S.                   95
# 1                          Da Vinci School                   47
# 2            Ecole elementaire Paul-Demers                   66
# 3                           Greenwood S.S.                  123
# 4              Alpha II Alternative School                   19
# ..                                     ...                  ...
# 801      South East Year Round Alternative                   27
# 802     Monsignor Fraser College - Midland                   16
# 803  Monsignor Fraser College - St. Martin                   16
# 804               Victoria Park Elementary                   92
# 805             East York Alternative S.S.                   60
#
#      DTP coverage rate (%)  MMR coverage rate (%)        Lat        Lng  freq  \
# 0                     57.9                   57.9  43.819348 -79.288303     4
# 1                     57.4                   59.6  43.658953 -79.401910    69
# 2                     53.0                   60.6  43.791952 -79.367340    11
# 3                     61.8                   64.2  43.682839 -79.334090    17
# 4                     52.6                   68.4  43.659557 -79.436283    22
# ..                     ...                    ...        ...        ...   ...
# 801                   92.6                  100.0  43.728101 -79.256689     4
# 802                   87.5                  100.0  43.801069 -79.285717    10
# 803                   62.5                  100.0  43.667175 -79.364426    67
# 804                   98.9                  100.0  43.712689 -79.298151    11
# 805                   90.0                  100.0  43.694991 -79.325296    13
#
#      Average vaccine coverage rate (%)  Average vaccine noncoverage rate (%)  \
# 0                                57.90                                 42.10
# 1                                58.50                                 41.50
# 2                                56.80                                 43.20
# 3                                63.00                                 37.00
# 4                                60.50                                 39.50
# ..                                 ...                                   ...
# 801                              96.30                                  3.70
# 802                              93.75                                  6.25
# 803                              81.25                                 18.75
# 804                              99.45                                  0.55
# 805                              95.00                                  5.00
#
#      Average vaccine noncoverage ratio
# 0                               0.4210
# 1                               0.4150
# 2                               0.4320
# 3                               0.3700
# 4                               0.3950
# ..                                 ...
# 801                             0.0370
# 802                             0.0625
# 803                             0.1875
# 804                             0.0055
# 805                             0.0500
#
# [806 rows x 10 columns]

# %%
# estimating total number of nonvaccinated students per school

df['Nonvaccinated students'] = df['Enrolled population']*df['Average vaccine noncoverage ratio']

df
# Out:
#                                School Name  Enrolled population  \
# 0                      St Rene Goupil C.S.                   95
# 1                          Da Vinci School                   47
# 2            Ecole elementaire Paul-Demers                   66
# 3                           Greenwood S.S.                  123
# 4              Alpha II Alternative School                   19
# ..                                     ...                  ...
# 801      South East Year Round Alternative                   27
# 802     Monsignor Fraser College - Midland                   16
# 803  Monsignor Fraser College - St. Martin                   16
# 804               Victoria Park Elementary                   92
# 805             East York Alternative S.S.                   60
#
#      DTP coverage rate (%)  MMR coverage rate (%)        Lat        Lng  freq  \
# 0                     57.9                   57.9  43.819348 -79.288303     4
# 1                     57.4                   59.6  43.658953 -79.401910    69
# 2                     53.0                   60.6  43.791952 -79.367340    11
# 3                     61.8                   64.2  43.682839 -79.334090    17
# 4                     52.6                   68.4  43.659557 -79.436283    22
# ..                     ...                    ...        ...        ...   ...
# 801                   92.6                  100.0  43.728101 -79.256689     4
# 802                   87.5                  100.0  43.801069 -79.285717    10
# 803                   62.5                  100.0  43.667175 -79.364426    67
# 804                   98.9                  100.0  43.712689 -79.298151    11
# 805                   90.0                  100.0  43.694991 -79.325296    13
#
#      Average vaccine coverage rate (%)  Average vaccine noncoverage rate (%)  \
# 0                                57.90                                 42.10
# 1                                58.50                                 41.50
# 2                                56.80                                 43.20
# 3                                63.00                                 37.00
# 4                                60.50                                 39.50
# ..                                 ...                                   ...
# 801                              96.30                                  3.70
# 802                              93.75                                  6.25
# 803                              81.25                                 18.75
# 804                              99.45                                  0.55
# 805                              95.00                                  5.00
#
#      Average vaccine noncoverage ratio  Nonvaccinated students
# 0                               0.4210                  39.995
# 1                               0.4150                  19.505
# 2                               0.4320                  28.512
# 3                               0.3700                  45.510
# 4                               0.3950                   7.505
# ..                                 ...                     ...
# 801                             0.0370                   0.999
# 802                             0.0625                   1.000
# 803                             0.1875                   3.000
# 804                             0.0055                   0.506
# 805                             0.0500                   3.000
#
# [806 rows x 11 columns]

# %%
# finding number of nonvaccinated students per clinic to understand overall demand for medical clinics in the nearby area

df['Nonvaccinated students/clinic'] = df['Nonvaccinated students']/df['freq']

df
# Out:
#                                School Name  Enrolled population  \
# 0                      St Rene Goupil C.S.                   95
# 1                          Da Vinci School                   47
# 2            Ecole elementaire Paul-Demers                   66
# 3                           Greenwood S.S.                  123
# 4              Alpha II Alternative School                   19
# ..                                     ...                  ...
# 801      South East Year Round Alternative                   27
# 802     Monsignor Fraser College - Midland                   16
# 803  Monsignor Fraser College - St. Martin                   16
# 804               Victoria Park Elementary                   92
# 805             East York Alternative S.S.                   60
#
#      DTP coverage rate (%)  MMR coverage rate (%)        Lat        Lng  freq  \
# 0                     57.9                   57.9  43.819348 -79.288303     4
# 1                     57.4                   59.6  43.658953 -79.401910    69
# 2                     53.0                   60.6  43.791952 -79.367340    11
# 3                     61.8                   64.2  43.682839 -79.334090    17
# 4                     52.6                   68.4  43.659557 -79.436283    22
# ..                     ...                    ...        ...        ...   ...
# 801                   92.6                  100.0  43.728101 -79.256689     4
# 802                   87.5                  100.0  43.801069 -79.285717    10
# 803                   62.5                  100.0  43.667175 -79.364426    67
# 804                   98.9                  100.0  43.712689 -79.298151    11
# 805                   90.0                  100.0  43.694991 -79.325296    13
#
#      Average vaccine coverage rate (%)  Average vaccine noncoverage rate (%)  \
# 0                                57.90                                 42.10
# 1                                58.50                                 41.50
# 2                                56.80                                 43.20
# 3                                63.00                                 37.00
# 4                                60.50                                 39.50
# ..                                 ...                                   ...
# 801                              96.30                                  3.70
# 802                              93.75                                  6.25
# 803                              81.25                                 18.75
# 804                              99.45                                  0.55
# 805                              95.00                                  5.00
#
#      Average vaccine noncoverage ratio  Nonvaccinated students  \
# 0                               0.4210                  39.995
# 1                               0.4150                  19.505
# 2                               0.4320                  28.512
# 3                               0.3700                  45.510
# 4                               0.3950                   7.505
# ..                                 ...                     ...
# 801                             0.0370                   0.999
# 802                             0.0625                   1.000
# 803                             0.1875                   3.000
# 804                             0.0055                   0.506
# 805                             0.0500                   3.000
#
#      Nonvaccinated students/clinic
# 0                         9.998750
# 1                         0.282681
# 2                         2.592000
# 3                         2.677059
# 4                         0.341136
# ..                             ...
# 801                       0.249750
# 802                       0.100000
# 803                       0.044776
# 804                       0.046000
# 805                       0.230769
#
# [806 rows x 12 columns]

# %%
# rounding values so they display nicely on the map

df['Nonvaccinated students'] = df['Nonvaccinated students'].round(2)
df['Nonvaccinated students/clinic'] = df['Nonvaccinated students/clinic'].round(2)

df
# Out:
#                                School Name  Enrolled population  \
# 0                      St Rene Goupil C.S.                   95
# 1                          Da Vinci School                   47
# 2            Ecole elementaire Paul-Demers                   66
# 3                           Greenwood S.S.                  123
# 4              Alpha II Alternative School                   19
# ..                                     ...                  ...
# 801      South East Year Round Alternative                   27
# 802     Monsignor Fraser College - Midland                   16
# 803  Monsignor Fraser College - St. Martin                   16
# 804               Victoria Park Elementary                   92
# 805             East York Alternative S.S.                   60
#
#      DTP coverage rate (%)  MMR coverage rate (%)        Lat        Lng  freq  \
# 0                     57.9                   57.9  43.819348 -79.288303     4
# 1                     57.4                   59.6  43.658953 -79.401910    69
# 2                     53.0                   60.6  43.791952 -79.367340    11
# 3                     61.8                   64.2  43.682839 -79.334090    17
# 4                     52.6                   68.4  43.659557 -79.436283    22
# ..                     ...                    ...        ...        ...   ...
# 801                   92.6                  100.0  43.728101 -79.256689     4
# 802                   87.5                  100.0  43.801069 -79.285717    10
# 803                   62.5                  100.0  43.667175 -79.364426    67
# 804                   98.9                  100.0  43.712689 -79.298151    11
# 805                   90.0                  100.0  43.694991 -79.325296    13
#
#      Average vaccine coverage rate (%)  Average vaccine noncoverage rate (%)  \
# 0                                57.90                                 42.10
# 1                                58.50                                 41.50
# 2                                56.80                                 43.20
# 3                                63.00                                 37.00
# 4                                60.50                                 39.50
# ..                                 ...                                   ...
# 801                              96.30                                  3.70
# 802                              93.75                                  6.25
# 803                              81.25                                 18.75
# 804                              99.45                                  0.55
# 805                              95.00                                  5.00
#
#      Average vaccine noncoverage ratio  Nonvaccinated students  \
# 0                               0.4210                   40.00
# 1                               0.4150                   19.50
# 2                               0.4320                   28.51
# 3                               0.3700                   45.51
# 4                               0.3950                    7.51
# ..                                 ...                     ...
# 801                             0.0370                    1.00
# 802                             0.0625                    1.00
# 803                             0.1875                    3.00
# 804                             0.0055                    0.51
# 805                             0.0500                    3.00
#
#      Nonvaccinated students/clinic
# 0                            10.00
# 1                             0.28
# 2                             2.59
# 3                             2.68
# 4                             0.34
# ..                             ...
# 801                           0.25
# 802                           0.10
# 803                           0.04
# 804                           0.05
# 805                           0.23
#
# [806 rows x 12 columns]

# %%
# displaying venue dataframe

df3
# Out:
#                       School Name  School Lat  School Lng  \
# 0             St Rene Goupil C.S.   43.819348  -79.288303
# 1             St Rene Goupil C.S.   43.819348  -79.288303
# 2             St Rene Goupil C.S.   43.819348  -79.288303
# 3             St Rene Goupil C.S.   43.819348  -79.288303
# 4                 Da Vinci School   43.658953  -79.401910
# ...                           ...         ...         ...
# 11495  East York Alternative S.S.   43.694991  -79.325296
# 11496  East York Alternative S.S.   43.694991  -79.325296
# 11497  East York Alternative S.S.   43.694991  -79.325296
# 11498  East York Alternative S.S.   43.694991  -79.325296
# 11499  East York Alternative S.S.   43.694991  -79.325296
#
#                                                Venue  Venue Latitude  \
# 0                         Silver Star Medical Centre       43.815107
# 1      Dr. Albert S.Y. Ng & Associates (Optometrist)       43.804021
# 2                            Dr. Norman Bethune C.I.       43.811589
# 3                 MCI The Doctor's Office (Bamburgh)       43.814874
# 4                            Totum Life Science King       43.645119
# ...                                              ...             ...
# 11495                Dawes Family Practice & Walk-In       43.689467
# 11496                       Appletree Medical Centre       43.713675
# 11497                    Crescent Town Health Centre       43.696474
# 11498                     German Roots in Russia PGS       43.674828
# 11499                           Nardini Naturopathic       43.677640
#
#        Venue Longitude   Venue Category  freq
# 0           -79.294900  Doctor's Office     4
# 1           -79.286738  Doctor's Office     4
# 2           -79.319662  Doctor's Office     4
# 3           -79.323283  Doctor's Office     4
# 4           -79.395883  Doctor's Office    69
# ...                ...              ...   ...
# 11495       -79.296951  Doctor's Office    13
# 11496       -79.306989  Doctor's Office    13
# 11497       -79.293405  Doctor's Office    13
# 11498       -79.342977  Doctor's Office    13
# 11499       -79.353116  Doctor's Office    13
#
# [11500 rows x 8 columns]

# %%
# cleaning venue dataframe

df3.drop(['School Name', 'School Lat', 'School Lng', 'Venue Category', 'freq'], axis = 1, inplace = True)
df3
# Out:
#                                                Venue  Venue Latitude  \
# 0                         Silver Star Medical Centre       43.815107
# 1      Dr. Albert S.Y. Ng & Associates (Optometrist)       43.804021
# 2                            Dr. Norman Bethune C.I.       43.811589
# 3                 MCI The Doctor's Office (Bamburgh)       43.814874
# 4                            Totum Life Science King       43.645119
# ...                                              ...             ...
# 11495                Dawes Family Practice & Walk-In       43.689467
# 11496                       Appletree Medical Centre       43.713675
# 11497                    Crescent Town Health Centre       43.696474
# 11498                     German Roots in Russia PGS       43.674828
# 11499                           Nardini Naturopathic       43.677640
#
#        Venue Longitude
# 0           -79.294900
# 1           -79.286738
# 2           -79.319662
# 3           -79.323283
# 4           -79.395883
# ...                ...
# 11495       -79.296951
# 11496       -79.306989
# 11497       -79.293405
# 11498       -79.342977
# 11499       -79.353116
#
# [11500 rows x 3 columns]

# %%
# dropping duplicates and resetting index

df3.drop_duplicates(inplace = True)
df3.reset_index(drop = True, inplace = True)
df3
# Out:
#                                                 Venue  Venue Latitude  \
# 0                          Silver Star Medical Centre       43.815107
# 1       Dr. Albert S.Y. Ng & Associates (Optometrist)       43.804021
# 2                             Dr. Norman Bethune C.I.       43.811589
# 3                  MCI The Doctor's Office (Bamburgh)       43.814874
# 4                             Totum Life Science King       43.645119
# ..                                                ...             ...
# 390  MCI The Doctor's Office At The Clinic In Walmart       43.835784
# 391                                      Dr. Sriharan       43.810699
# 392                            Dr. R.S. Rana's office       43.820171
# 393                              Dr. Judith Nacua M.D       43.798225
# 394                                   Mini Med Clinic       43.636541
#
#      Venue Longitude
# 0         -79.294900
# 1         -79.286738
# 2         -79.319662
# 3         -79.323283
# 4         -79.395883
# ..               ...
# 390       -79.255757
# 391       -79.255699
# 392       -79.261795
# 393       -79.216995
# 394       -79.520745
#
# [395 rows x 3 columns]

# %%
# creating map of Toronto with school and venue data
map_toronto_2 = folium.Map(location=[latitude, longitude], zoom_start=10.7)

# adding school markers to map
for lat, lng, school, non in zip(df['Lat'], df['Lng'], df['School Name'], df['Nonvaccinated students/clinic']):
    label = ("{}, Estimated nonvaccinated students/clinic: {}").format(school, non)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=4,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto_2)
    

# adding venue markers to map    
for lat, lng, venue in zip(df3["Venue Latitude"], df3["Venue Longitude"], df3["Venue"]):
    label = ("{}").format(venue)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='red',
        fill=True,
        fill_color='#f76f6a',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto_2)
    
# generating map    
map_toronto_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Figure 2. Map showing estimated nonvaccinated students/clinic for each school, and every medical clinic within 3 km of each school in Toronto. The blue markers represent the schools and the red markers represent the medical clinics.

# %%
# sorting dataframe by nonvaccinated students to see the schools with the greatest population of nonvaccinated students

df = df.sort_values(['Nonvaccinated students'], ascending=False).reset_index(drop=True)

df
# Out:
#                             School Name  Enrolled population  \
# 0          Michael Power/St Joseph H.S.                 1818
# 1                     Marc Garneau C.I.                 1629
# 2    Bishop Allen Academy Catholic S.S.                 1540
# 3                Northview Heights S.S.                 1490
# 4                         Northern S.S.                 1678
# ..                                  ...                  ...
# 801   South East Year Round Alternative                   27
# 802  Monsignor Fraser College - Midland                   16
# 803            Victoria Park Elementary                   92
# 804                   Kimberley Jr P.S.                  160
# 805              Anson S Taylor Jr P.S.                  122
#
#      DTP coverage rate (%)  MMR coverage rate (%)        Lat        Lng  freq  \
# 0                     84.6                   95.5  43.659290 -79.581984     5
# 1                     83.2                   95.0  43.708976 -79.334968    10
# 2                     85.1                   93.6  43.634428 -79.504465    11
# 3                     84.6                   93.7  43.774429 -79.446325    14
# 4                     85.3                   95.8  43.710537 -79.390164    30
# ..                     ...                    ...        ...        ...   ...
# 801                   92.6                  100.0  43.728101 -79.256689     4
# 802                   87.5                  100.0  43.801069 -79.285717    10
# 803                   98.9                  100.0  43.712689 -79.298151    11
# 804                  100.0                  100.0  43.682620 -79.299128    13
# 805                  100.0                  100.0  43.804292 -79.261561     6
#
#      Average vaccine coverage rate (%)  Average vaccine noncoverage rate (%)  \
# 0                                90.05                                  9.95
# 1                                89.10                                 10.90
# 2                                89.35                                 10.65
# 3                                89.15                                 10.85
# 4                                90.55                                  9.45
# ..                                 ...                                   ...
# 801                              96.30                                  3.70
# 802                              93.75                                  6.25
# 803                              99.45                                  0.55
# 804                             100.00                                  0.00
# 805                             100.00                                  0.00
#
#      Average vaccine noncoverage ratio  Nonvaccinated students  \
# 0                               0.0995                  180.89
# 1                               0.1090                  177.56
# 2                               0.1065                  164.01
# 3                               0.1085                  161.66
# 4                               0.0945                  158.57
# ..                                 ...                     ...
# 801                             0.0370                    1.00
# 802                             0.0625                    1.00
# 803                             0.0055                    0.51
# 804                             0.0000                    0.00
# 805                             0.0000                    0.00
#
#      Nonvaccinated students/clinic
# 0                            36.18
# 1                            17.76
# 2                            14.91
# 3                            11.55
# 4                             5.29
# ..                             ...
# 801                           0.25
# 802                           0.10
# 803                           0.05
# 804                           0.00
# 805                           0.00
#
# [806 rows x 12 columns]

# %%
# sorting dataframe by nonvaccinated students/clinic to see the schools with the highest ratio of unvaccinated students per clinic

df = df.sort_values(['Nonvaccinated students/clinic'], ascending=False).reset_index(drop=True)

df
# Out:
#                                School Name  Enrolled population  \
# 0    Monsignor Percy Johnson Catholic H.S.                  936
# 1               Josyf Cardinal Slipyj C.S.                  395
# 2              St. Basil The Great College                 1258
# 3       St. Mother Teresa Catholic Academy                  413
# 4                         St Benedict C.S.                  436
# ..                                     ...                  ...
# 801  Monsignor Fraser College - St. Martin                   16
# 802                       Rosedale Jr P.S.                  151
# 803                       Montrose Jr P.S.                  112
# 804                      Kimberley Jr P.S.                  160
# 805                 Anson S Taylor Jr P.S.                  122
#
#      DTP coverage rate (%)  MMR coverage rate (%)        Lat        Lng  freq  \
# 0                     84.9                   94.7  43.720695 -79.572017     1
# 1                     84.8                   84.8  43.659475 -79.566025     1
# 2                     86.2                   95.1  43.727168 -79.533451     2
# 3                     83.5                   90.1  43.807243 -79.217789     1
# 4                     86.5                   89.4  43.720695 -79.572017     1
# ..                     ...                    ...        ...        ...   ...
# 801                   62.5                  100.0  43.667175 -79.364426    67
# 802                   98.7                   98.7  43.677656 -79.381686    53
# 803                   99.1                   98.2  43.658682 -79.418844    53
# 804                  100.0                  100.0  43.682620 -79.299128    13
# 805                  100.0                  100.0  43.804292 -79.261561     6
#
#      Average vaccine coverage rate (%)  Average vaccine noncoverage rate (%)  \
# 0                                89.80                                 10.20
# 1                                84.80                                 15.20
# 2                                90.65                                  9.35
# 3                                86.80                                 13.20
# 4                                87.95                                 12.05
# ..                                 ...                                   ...
# 801                              81.25                                 18.75
# 802                              98.70                                  1.30
# 803                              98.65                                  1.35
# 804                             100.00                                  0.00
# 805                             100.00                                  0.00
#
#      Average vaccine noncoverage ratio  Nonvaccinated students  \
# 0                               0.1020                   95.47
# 1                               0.1520                   60.04
# 2                               0.0935                  117.62
# 3                               0.1320                   54.52
# 4                               0.1205                   52.54
# ..                                 ...                     ...
# 801                             0.1875                    3.00
# 802                             0.0130                    1.96
# 803                             0.0135                    1.51
# 804                             0.0000                    0.00
# 805                             0.0000                    0.00
#
#      Nonvaccinated students/clinic
# 0                            95.47
# 1                            60.04
# 2                            58.81
# 3                            54.52
# 4                            52.54
# ..                             ...
# 801                           0.04
# 802                           0.04
# 803                           0.03
# 804                           0.00
# 805                           0.00
#
# [806 rows x 12 columns]

# %%
# checking dataframe to see any trends

df.head(60)
# Out:
#                                School Name  Enrolled population  \
# 0    Monsignor Percy Johnson Catholic H.S.                  936
# 1               Josyf Cardinal Slipyj C.S.                  395
# 2              St. Basil The Great College                 1258
# 3       St. Mother Teresa Catholic Academy                  413
# 4                         St Benedict C.S.                  436
# 5                     St John Vianney C.S.                  282
# 6             Michael Power/St Joseph H.S.                 1818
# 7                 Hollycrest Middle School                  475
# 8        Father John Redmond Catholic S.S.                 1187
# 9                            Richview C.I.                 1035
# 10                             Weston C.I.                  894
# 11                  Brebeuf College School                  852
# 12                          St Angela C.S.                  397
# 13                        West Humber C.I.                 1016
# 14                          St Andrew C.S.                  550
# 15         Father Henry Carr Catholic S.S.                  850
# 16                   Lester B Pearson C.I.                 1291
# 17                        Martingrove C.I.                 1088
# 18                   Sir Oliver Mowat C.I.                 1048
# 19                    Albert Campbell C.I.                 1072
# 20                         St Bernard C.S.                  478
# 21                        Silverthorn C.I.                  834
# 22             Venerable John Merlini C.S.                  210
# 23                Westview Centennial S.S.                  763
# 24                        A Y Jackson S.S.                 1027
# 25                      Alvin Curling P.S.                  383
# 26                            Kipling C.I.                  410
# 27                           St Andre C.S.                  419
# 28                       Marc Garneau C.I.                 1629
# 29  Wexford Collegiate School for The Arts                 1084
# 30                         All Saints C.S.                  643
# 31          St. John Paul II Catholic S.S.                 1276
# 32                          Don Mills C.I.                  935
# 33                Senator O'Connor College                 1321
# 34         Francis Libermann Catholic H.S.                  878
# 35                       North Albion C.I.                  757
# 36   Western Technical & Commercial School                  975
# 37             William Lyon Mackenzie C.I.                 1377
# 38                    Birchmount Park C.I.                  833
# 39                            St Jude C.S.                  542
# 40   James Cardinal McGuigan Catholic H.S.                  794
# 41               Jean Vanier Catholic S.S.                  821
# 42                Our Lady of Victory C.S.                  485
# 43      Bishop Allen Academy Catholic S.S.                 1540
# 44                      York Memorial C.I.                  876
# 45                        Thistletown C.I.                  441
# 46                          Lakeshore C.I.                  603
# 47                Sir Wilfrid Laurier C.I.                 1319
# 48                Chaminade College School                  913
# 49             St Josephs Morrow Park H.S.                  459
# 50                        Newtonbrook S.S.                  749
# 51                      George Harvey C.I.                  401
# 52                   The Holy Trinity C.S.                  317
# 53           John G Althouse Middle School                  480
# 54                          West Hill C.I.                  631
# 55                       St Marcellus C.S.                  286
# 56                              Emery C.I.                  484
# 57            Etobicoke School of The Arts                  929
# 58                  St Paschal Baylon C.S.                  522
# 59                         Dixon Grove JMS                  594
#
#     DTP coverage rate (%)  MMR coverage rate (%)        Lat        Lng  freq  \
# 0                    84.9                   94.7  43.720695 -79.572017     1
# 1                    84.8                   84.8  43.659475 -79.566025     1
# 2                    86.2                   95.1  43.727168 -79.533451     2
# 3                    83.5                   90.1  43.807243 -79.217789     1
# 4                    86.5                   89.4  43.720695 -79.572017     1
# 5                    86.9                   86.2  43.737976 -79.553846     1
# 6                    84.6                   95.5  43.659290 -79.581984     5
# 7                    90.7                   94.3  43.656104 -79.582708     1
# 8                    83.0                   94.4  43.595141 -79.516539     4
# 9                    84.8                   96.8  43.678869 -79.538912     3
# 10                   84.2                   95.3  43.703816 -79.509422     3
# 11                   81.6                   90.6  43.801516 -79.403038     4
# 12                   77.6                   81.1  43.753387 -79.595791     3
# 13                   85.2                   96.1  43.730922 -79.586705     4
# 14                   79.3                   86.4  43.744931 -79.582382     4
# 15                   83.8                   94.5  43.735842 -79.592378     4
# 16                   88.0                   98.3  43.803334 -79.225399     4
# 17                   86.8                   97.1  43.673383 -79.560740     4
# 18                   86.5                   97.1  43.779302 -79.142238     4
# 19                   88.2                   96.8  43.809014 -79.273407     4
# 20                   86.6                   88.7  43.702506 -79.500608     3
# 21                   82.0                   95.2  43.637836 -79.580389     5
# 22                   88.1                   93.8  43.756481 -79.579384     1
# 23                   81.3                   93.8  43.752398 -79.525091     5
# 24                   89.0                   96.5  43.805261 -79.366555     4
# 25                   94.5                   95.8  43.808492 -79.190634     1
# 26                   75.4                   89.5  43.685288 -79.562354     4
# 27                   86.2                   88.1  43.723995 -79.517633     3
# 28                   83.2                   95.0  43.708976 -79.334968    10
# 29                   84.0                   96.5  43.746160 -79.306795     6
# 30                   87.4                   91.0  43.685618 -79.527163     4
# 31                   86.8                   97.2  43.789115 -79.197117     6
# 32                   86.5                   95.7  43.735959 -79.339277     5
# 33                   85.5                   94.7  43.750827 -79.317369     8
# 34                   86.0                   95.4  43.807392 -79.274308     5
# 35                   85.1                   98.0  43.747142 -79.585143     4
# 36                   80.3                   93.7  43.657091 -79.474582     8
# 37                   84.9                   94.6  43.753471 -79.461894     9
# 38                   85.1                   96.2  43.697753 -79.259455     5
# 39                   86.5                   91.0  43.740484 -79.539257     4
# 40                   76.8                   85.1  43.763290 -79.493799    10
# 41                   82.7                   91.6  43.737940 -79.258414     7
# 42                   86.6                   88.7  43.683321 -79.490315     4
# 43                   85.1                   93.6  43.634428 -79.504465    11
# 44                   86.8                   96.3  43.690279 -79.476240     5
# 45                   82.8                   97.1  43.727727 -79.562453     3
# 46                   81.6                   94.0  43.601563 -79.519161     5
# 47                   87.2                   97.3  43.747034 -79.196991     7
# 48                   89.6                   97.8  43.710091 -79.496059     4
# 49                   81.3                   88.5  43.797137 -79.392081     5
# 50                   80.6                   89.9  43.793549 -79.426243     8
# 51                   80.0                   85.8  43.684547 -79.473699     5
# 52                   82.0                   84.2  43.595141 -79.516539     4
# 53                   93.1                   96.0  43.668116 -79.554161     2
# 54                   83.8                   95.7  43.775668 -79.190588     5
# 55                   81.1                   82.9  43.679792 -79.554225     4
# 56                   85.5                   93.8  43.748723 -79.539557     4
# 57                   80.1                   93.4  43.630732 -79.504149    10
# 58                   84.7                   82.6  43.792201 -79.431322     7
# 59                   89.9                   93.9  43.684709 -79.555955     4
#
#     Average vaccine coverage rate (%)  Average vaccine noncoverage rate (%)  \
# 0                               89.80                                 10.20
# 1                               84.80                                 15.20
# 2                               90.65                                  9.35
# 3                               86.80                                 13.20
# 4                               87.95                                 12.05
# 5                               86.55                                 13.45
# 6                               90.05                                  9.95
# 7                               92.50                                  7.50
# 8                               88.70                                 11.30
# 9                               90.80                                  9.20
# 10                              89.75                                 10.25
# 11                              86.10                                 13.90
# 12                              79.35                                 20.65
# 13                              90.65                                  9.35
# 14                              82.85                                 17.15
# 15                              89.15                                 10.85
# 16                              93.15                                  6.85
# 17                              91.95                                  8.05
# 18                              91.80                                  8.20
# 19                              92.50                                  7.50
# 20                              87.65                                 12.35
# 21                              88.60                                 11.40
# 22                              90.95                                  9.05
# 23                              87.55                                 12.45
# 24                              92.75                                  7.25
# 25                              95.15                                  4.85
# 26                              82.45                                 17.55
# 27                              87.15                                 12.85
# 28                              89.10                                 10.90
# 29                              90.25                                  9.75
# 30                              89.20                                 10.80
# 31                              92.00                                  8.00
# 32                              91.10                                  8.90
# 33                              90.10                                  9.90
# 34                              90.70                                  9.30
# 35                              91.55                                  8.45
# 36                              87.00                                 13.00
# 37                              89.75                                 10.25
# 38                              90.65                                  9.35
# 39                              88.75                                 11.25
# 40                              80.95                                 19.05
# 41                              87.15                                 12.85
# 42                              87.65                                 12.35
# 43                              89.35                                 10.65
# 44                              91.55                                  8.45
# 45                              89.95                                 10.05
# 46                              87.80                                 12.20
# 47                              92.25                                  7.75
# 48                              93.70                                  6.30
# 49                              84.90                                 15.10
# 50                              85.25                                 14.75
# 51                              82.90                                 17.10
# 52                              83.10                                 16.90
# 53                              94.55                                  5.45
# 54                              89.75                                 10.25
# 55                              82.00                                 18.00
# 56                              89.65                                 10.35
# 57                              86.75                                 13.25
# 58                              83.65                                 16.35
# 59                              91.90                                  8.10
#
#     Average vaccine noncoverage ratio  Nonvaccinated students  \
# 0                              0.1020                   95.47
# 1                              0.1520                   60.04
# 2                              0.0935                  117.62
# 3                              0.1320                   54.52
# 4                              0.1205                   52.54
# 5                              0.1345                   37.93
# 6                              0.0995                  180.89
# 7                              0.0750                   35.62
# 8                              0.1130                  134.13
# 9                              0.0920                   95.22
# 10                             0.1025                   91.64
# 11                             0.1390                  118.43
# 12                             0.2065                   81.98
# 13                             0.0935                   95.00
# 14                             0.1715                   94.33
# 15                             0.1085                   92.22
# 16                             0.0685                   88.43
# 17                             0.0805                   87.58
# 18                             0.0820                   85.94
# 19                             0.0750                   80.40
# 20                             0.1235                   59.03
# 21                             0.1140                   95.08
# 22                             0.0905                   19.01
# 23                             0.1245                   94.99
# 24                             0.0725                   74.46
# 25                             0.0485                   18.58
# 26                             0.1755                   71.95
# 27                             0.1285                   53.84
# 28                             0.1090                  177.56
# 29                             0.0975                  105.69
# 30                             0.1080                   69.44
# 31                             0.0800                  102.08
# 32                             0.0890                   83.22
# 33                             0.0990                  130.78
# 34                             0.0930                   81.65
# 35                             0.0845                   63.97
# 36                             0.1300                  126.75
# 37                             0.1025                  141.14
# 38                             0.0935                   77.89
# 39                             0.1125                   60.98
# 40                             0.1905                  151.26
# 41                             0.1285                  105.50
# 42                             0.1235                   59.90
# 43                             0.1065                  164.01
# 44                             0.0845                   74.02
# 45                             0.1005                   44.32
# 46                             0.1220                   73.57
# 47                             0.0775                  102.22
# 48                             0.0630                   57.52
# 49                             0.1510                   69.31
# 50                             0.1475                  110.48
# 51                             0.1710                   68.57
# 52                             0.1690                   53.57
# 53                             0.0545                   26.16
# 54                             0.1025                   64.68
# 55                             0.1800                   51.48
# 56                             0.1035                   50.09
# 57                             0.1325                  123.09
# 58                             0.1635                   85.35
# 59                             0.0810                   48.11
#
#     Nonvaccinated students/clinic
# 0                           95.47
# 1                           60.04
# 2                           58.81
# 3                           54.52
# 4                           52.54
# 5                           37.93
# 6                           36.18
# 7                           35.62
# 8                           33.53
# 9                           31.74
# 10                          30.54
# 11                          29.61
# 12                          27.33
# 13                          23.75
# 14                          23.58
# 15                          23.06
# 16                          22.11
# 17                          21.90
# 18                          21.48
# 19                          20.10
# 20                          19.68
# 21                          19.02
# 22                          19.01
# 23                          19.00
# 24                          18.61
# 25                          18.58
# 26                          17.99
# 27                          17.95
# 28                          17.76
# 29                          17.61
# 30                          17.36
# 31                          17.01
# 32                          16.64
# 33                          16.35
# 34                          16.33
# 35                          15.99
# 36                          15.84
# 37                          15.68
# 38                          15.58
# 39                          15.24
# 40                          15.13
# 41                          15.07
# 42                          14.97
# 43                          14.91
# 44                          14.80
# 45                          14.77
# 46                          14.71
# 47                          14.60
# 48                          14.38
# 49                          13.86
# 50                          13.81
# 51                          13.71
# 52                          13.39
# 53                          13.08
# 54                          12.94
# 55                          12.87
# 56                          12.52
# 57                          12.31
# 58                          12.19
# 59                          12.03

# %%
# checking bottom of dataframe - interesting to note that a considerable number of schools at the bottom of the dataframe tend to have low population sizes, perhaps some of these are schools with more stringent vaccination requirements

df.tail(60)
# Out:
#                                     School Name  Enrolled population  \
# 746                               Harrison P.S.                  102
# 747                     Spectrum Alternative Sr                   60
# 748                        George Anderson P.S.                   91
# 749    Monsignor Fraser College - Midland North                   28
# 750                             Whitney Jr P.S.                  161
# 751                    Nelson Mandela Park P.S.                  234
# 752                      Clinton Street Jr P.S.                  273
# 753                        Quest Alternative Sr                   66
# 754                         Orde Street Jr P.S.                  243
# 755                   St Francis of Assisi C.S.                  123
# 756           North East Year Round Alternative                   29
# 757                        Huron Street Jr P.S.                  202
# 758  Monsignor Fraser College - Alternate Study                  106
# 759          East Alternative School of Toronto                   62
# 760                           Oasis Alternative                   72
# 761                       Rolph Road Elementary                  235
# 762                          Vradenburg Jr P.S.                  145
# 763     Etobicoke Year Round Alternative Centre                   26
# 764                            Heydon Park S.S.                   91
# 765                 Alpha Alternative Jr School                   49
# 766                            Seneca Hill P.S.                  195
# 767               Horizon Alternative Sr School                   67
# 768                St Michael's Choir Jr School                  169
# 769                       The Waterfront School                  142
# 770                        West End Alternative                   49
# 771                           Golf Road Jr P.S.                  190
# 772                  Lord Dufferin Jr & Sr P.S.                  306
# 773                  Inglenook Community School                   50
# 774                         Sprucecourt Jr P.S.                  194
# 775                               Edgewood P.S.                  119
# 776          Monsignor Fraser College - Midtown                   26
# 777                    Delta Senior Alternative                   60
# 778                St Michael's Choir Sr School                   88
# 779                    Charles G Fraser Jr P.S.                  138
# 780                 Brookmill Boulevard Jr P.S.                  152
# 781                 Kensington Community School                   95
# 782                           Agincourt Jr P.S.                  141
# 783                             Beverley School                   64
# 784                    George R Gauld Jr School                   75
# 785                      Lord Lansdowne Jr P.S.                  174
# 786                      Niagara Street Jr P.S.                  125
# 787          Monsignor Fraser College - Midland                   16
# 788                  Contact Alternative School                   35
# 789                          Cottingham Jr P.S.                  100
# 790         Monsignor Fraser College - Isabella                   14
# 791                            Seed Alternative                   31
# 792                 Downtown Alternative School                   66
# 793                               Ogden Jr P.S.                  116
# 794                   School of Life Experience                   28
# 795     Downtown Vocal Music Academy of Toronto                   47
# 796         Alternative Scarborough Education 1                   15
# 797                           Subway Academy II                   19
# 798                    Victoria Park Elementary                   92
# 799               Bennington Heights Elementary                  129
# 800                      Native Learning Centre                   15
# 801       Monsignor Fraser College - St. Martin                   16
# 802                            Rosedale Jr P.S.                  151
# 803                            Montrose Jr P.S.                  112
# 804                           Kimberley Jr P.S.                  160
# 805                      Anson S Taylor Jr P.S.                  122
#
#      DTP coverage rate (%)  MMR coverage rate (%)        Lat        Lng  freq  \
# 746                   97.1                   97.1  43.757368 -79.377309    14
# 747                   88.3                   91.7  43.699276 -79.394896    28
# 748                  100.0                   96.7  43.705454 -79.478948     7
# 749                   89.3                   96.4  43.801069 -79.285717    10
# 750                   95.7                   95.7  43.687160 -79.378397    37
# 751                   94.0                   94.9  43.658353 -79.360603    67
# 752                   95.6                   96.0  43.657646 -79.414058    60
# 753                   86.4                   89.4  43.670460 -79.352130    43
# 754                   96.3                   92.6  43.658627 -79.392260    71
# 755                   87.8                   93.5  43.656200 -79.414628    61
# 756                   86.2                   93.1  43.784292 -79.350496    16
# 757                   93.6                   95.5  43.671038 -79.402411    60
# 758                   82.1                   95.3  43.669799 -79.377153    67
# 759                   91.9                   96.8  43.671806 -79.338476    19
# 760                   75.0                   88.9  43.645722 -79.398223    72
# 761                   97.4                   97.4  43.699784 -79.366251    36
# 762                   98.6                   98.6  43.774342 -79.308286    12
# 763                   88.5                   96.2  43.633858 -79.551276    12
# 764                   75.8                   97.8  43.654965 -79.394535    72
# 765                   75.5                   77.6  43.645722 -79.398223    72
# 766                   99.0                   98.5  43.790870 -79.350297    15
# 767                   85.1                   91.0  43.657978 -79.421999    49
# 768                   92.9                   94.1  43.655446 -79.377687    75
# 769                   94.4                   92.3  43.635749 -79.397188    64
# 770                   81.6                   89.8  43.662430 -79.419834    48
# 771                   98.4                   99.5  43.763658 -79.216970    13
# 772                   95.8                   96.7  43.660825 -79.366955    75
# 773                   78.0                   88.0  43.653975 -79.359401    62
# 774                   92.8                   96.9  43.664486 -79.363830    70
# 775                   98.3                   98.3  43.766305 -79.265812    14
# 776                   69.2                   96.2  43.706595 -79.399961    32
# 777                   88.3                   88.3  43.658682 -79.418844    53
# 778                   83.0                   95.5  43.655446 -79.377687    75
# 779                   92.8                   94.9  43.648530 -79.409484    69
# 780                  100.0                   98.0  43.801220 -79.314868    13
# 781                   90.5                   91.6  43.656398 -79.405732    70
# 782                   99.3                   98.6  43.788406 -79.281172    12
# 783                   84.4                   87.5  43.655765 -79.395705    72
# 784                   96.0                  100.0  43.620637 -79.498519    12
# 785                   95.4                   96.0  43.658953 -79.401910    69
# 786                   92.0                   96.8  43.643937 -79.408253    68
# 787                   87.5                  100.0  43.801069 -79.285717    10
# 788                   68.6                   94.3  43.653766 -79.390394    72
# 789                   96.0                   96.0  43.680379 -79.395609    44
# 790                   42.9                   71.4  43.669799 -79.377153    67
# 791                   80.6                   90.3  43.662078 -79.348686    48
# 792                   92.4                   90.9  43.647736 -79.370416    66
# 793                   96.6                   94.8  43.650014 -79.395127    76
# 794                   92.9                   96.4  43.679281 -79.322772    20
# 795                   87.2                   89.4  43.651221 -79.402637    76
# 796                   86.7                  100.0  43.766645 -79.254796    15
# 797                   78.9                   78.9  43.655765 -79.395705    72
# 798                   98.9                  100.0  43.712689 -79.298151    11
# 799                   99.2                   98.4  43.693882 -79.369553    32
# 800                   66.7                   86.7  43.663608 -79.379178    67
# 801                   62.5                  100.0  43.667175 -79.364426    67
# 802                   98.7                   98.7  43.677656 -79.381686    53
# 803                   99.1                   98.2  43.658682 -79.418844    53
# 804                  100.0                  100.0  43.682620 -79.299128    13
# 805                  100.0                  100.0  43.804292 -79.261561     6
#
#      Average vaccine coverage rate (%)  Average vaccine noncoverage rate (%)  \
# 746                              97.10                                  2.90
# 747                              90.00                                 10.00
# 748                              98.35                                  1.65
# 749                              92.85                                  7.15
# 750                              95.70                                  4.30
# 751                              94.45                                  5.55
# 752                              95.80                                  4.20
# 753                              87.90                                 12.10
# 754                              94.45                                  5.55
# 755                              90.65                                  9.35
# 756                              89.65                                 10.35
# 757                              94.55                                  5.45
# 758                              88.70                                 11.30
# 759                              94.35                                  5.65
# 760                              81.95                                 18.05
# 761                              97.40                                  2.60
# 762                              98.60                                  1.40
# 763                              92.35                                  7.65
# 764                              86.80                                 13.20
# 765                              76.55                                 23.45
# 766                              98.75                                  1.25
# 767                              88.05                                 11.95
# 768                              93.50                                  6.50
# 769                              93.35                                  6.65
# 770                              85.70                                 14.30
# 771                              98.95                                  1.05
# 772                              96.25                                  3.75
# 773                              83.00                                 17.00
# 774                              94.85                                  5.15
# 775                              98.30                                  1.70
# 776                              82.70                                 17.30
# 777                              88.30                                 11.70
# 778                              89.25                                 10.75
# 779                              93.85                                  6.15
# 780                              99.00                                  1.00
# 781                              91.05                                  8.95
# 782                              98.95                                  1.05
# 783                              85.95                                 14.05
# 784                              98.00                                  2.00
# 785                              95.70                                  4.30
# 786                              94.40                                  5.60
# 787                              93.75                                  6.25
# 788                              81.45                                 18.55
# 789                              96.00                                  4.00
# 790                              57.15                                 42.85
# 791                              85.45                                 14.55
# 792                              91.65                                  8.35
# 793                              95.70                                  4.30
# 794                              94.65                                  5.35
# 795                              88.30                                 11.70
# 796                              93.35                                  6.65
# 797                              78.90                                 21.10
# 798                              99.45                                  0.55
# 799                              98.80                                  1.20
# 800                              76.70                                 23.30
# 801                              81.25                                 18.75
# 802                              98.70                                  1.30
# 803                              98.65                                  1.35
# 804                             100.00                                  0.00
# 805                             100.00                                  0.00
#
#      Average vaccine noncoverage ratio  Nonvaccinated students  \
# 746                             0.0290                    2.96
# 747                             0.1000                    6.00
# 748                             0.0165                    1.50
# 749                             0.0715                    2.00
# 750                             0.0430                    6.92
# 751                             0.0555                   12.99
# 752                             0.0420                   11.47
# 753                             0.1210                    7.99
# 754                             0.0555                   13.49
# 755                             0.0935                   11.50
# 756                             0.1035                    3.00
# 757                             0.0545                   11.01
# 758                             0.1130                   11.98
# 759                             0.0565                    3.50
# 760                             0.1805                   13.00
# 761                             0.0260                    6.11
# 762                             0.0140                    2.03
# 763                             0.0765                    1.99
# 764                             0.1320                   12.01
# 765                             0.2345                   11.49
# 766                             0.0125                    2.44
# 767                             0.1195                    8.01
# 768                             0.0650                   10.99
# 769                             0.0665                    9.44
# 770                             0.1430                    7.01
# 771                             0.0105                    1.99
# 772                             0.0375                   11.48
# 773                             0.1700                    8.50
# 774                             0.0515                    9.99
# 775                             0.0170                    2.02
# 776                             0.1730                    4.50
# 777                             0.1170                    7.02
# 778                             0.1075                    9.46
# 779                             0.0615                    8.49
# 780                             0.0100                    1.52
# 781                             0.0895                    8.50
# 782                             0.0105                    1.48
# 783                             0.1405                    8.99
# 784                             0.0200                    1.50
# 785                             0.0430                    7.48
# 786                             0.0560                    7.00
# 787                             0.0625                    1.00
# 788                             0.1855                    6.49
# 789                             0.0400                    4.00
# 790                             0.4285                    6.00
# 791                             0.1455                    4.51
# 792                             0.0835                    5.51
# 793                             0.0430                    4.99
# 794                             0.0535                    1.50
# 795                             0.1170                    5.50
# 796                             0.0665                    1.00
# 797                             0.2110                    4.01
# 798                             0.0055                    0.51
# 799                             0.0120                    1.55
# 800                             0.2330                    3.49
# 801                             0.1875                    3.00
# 802                             0.0130                    1.96
# 803                             0.0135                    1.51
# 804                             0.0000                    0.00
# 805                             0.0000                    0.00
#
#      Nonvaccinated students/clinic
# 746                           0.21
# 747                           0.21
# 748                           0.21
# 749                           0.20
# 750                           0.19
# 751                           0.19
# 752                           0.19
# 753                           0.19
# 754                           0.19
# 755                           0.19
# 756                           0.19
# 757                           0.18
# 758                           0.18
# 759                           0.18
# 760                           0.18
# 761                           0.17
# 762                           0.17
# 763                           0.17
# 764                           0.17
# 765                           0.16
# 766                           0.16
# 767                           0.16
# 768                           0.15
# 769                           0.15
# 770                           0.15
# 771                           0.15
# 772                           0.15
# 773                           0.14
# 774                           0.14
# 775                           0.14
# 776                           0.14
# 777                           0.13
# 778                           0.13
# 779                           0.12
# 780                           0.12
# 781                           0.12
# 782                           0.12
# 783                           0.12
# 784                           0.12
# 785                           0.11
# 786                           0.10
# 787                           0.10
# 788                           0.09
# 789                           0.09
# 790                           0.09
# 791                           0.09
# 792                           0.08
# 793                           0.07
# 794                           0.07
# 795                           0.07
# 796                           0.07
# 797                           0.06
# 798                           0.05
# 799                           0.05
# 800                           0.05
# 801                           0.04
# 802                           0.04
# 803                           0.03
# 804                           0.00
# 805                           0.00

# %%
# slicing dataframe to show only top 10% of schools 

topdecile = df[0:80]
topdecile
# Out:
#                               School Name  Enrolled population  \
# 0   Monsignor Percy Johnson Catholic H.S.                  936
# 1              Josyf Cardinal Slipyj C.S.                  395
# 2             St. Basil The Great College                 1258
# 3      St. Mother Teresa Catholic Academy                  413
# 4                        St Benedict C.S.                  436
# ..                                    ...                  ...
# 75               Satec at W A Porter C.I.                 1181
# 76                   Joseph Brant Sr P.S.                  459
# 77                      John Polanyi C.I.                  743
# 78           Pierre Laporte Middle School                  398
# 79                    St Rene Goupil C.S.                   95
#
#     DTP coverage rate (%)  MMR coverage rate (%)        Lat        Lng  freq  \
# 0                    84.9                   94.7  43.720695 -79.572017     1
# 1                    84.8                   84.8  43.659475 -79.566025     1
# 2                    86.2                   95.1  43.727168 -79.533451     2
# 3                    83.5                   90.1  43.807243 -79.217789     1
# 4                    86.5                   89.4  43.720695 -79.572017     1
# ..                    ...                    ...        ...        ...   ...
# 75                   88.0                   96.4  43.716593 -79.287270     9
# 76                   86.9                   90.8  43.767044 -79.175498     5
# 77                   79.1                   87.9  43.717809 -79.439855    12
# 78                   88.2                   91.7  43.725075 -79.492124     4
# 79                   57.9                   57.9  43.819348 -79.288303     4
#
#     Average vaccine coverage rate (%)  Average vaccine noncoverage rate (%)  \
# 0                               89.80                                 10.20
# 1                               84.80                                 15.20
# 2                               90.65                                  9.35
# 3                               86.80                                 13.20
# 4                               87.95                                 12.05
# ..                                ...                                   ...
# 75                              92.20                                  7.80
# 76                              88.85                                 11.15
# 77                              83.50                                 16.50
# 78                              89.95                                 10.05
# 79                              57.90                                 42.10
#
#     Average vaccine noncoverage ratio  Nonvaccinated students  \
# 0                              0.1020                   95.47
# 1                              0.1520                   60.04
# 2                              0.0935                  117.62
# 3                              0.1320                   54.52
# 4                              0.1205                   52.54
# ..                                ...                     ...
# 75                             0.0780                   92.12
# 76                             0.1115                   51.18
# 77                             0.1650                  122.60
# 78                             0.1005                   40.00
# 79                             0.4210                   40.00
#
#     Nonvaccinated students/clinic
# 0                           95.47
# 1                           60.04
# 2                           58.81
# 3                           54.52
# 4                           52.54
# ..                            ...
# 75                          10.24
# 76                          10.24
# 77                          10.22
# 78                          10.00
# 79                          10.00
#
# [80 rows x 12 columns]

# %%
# slicing dataframe to show only top 10% of schools 

bottomdecile = df[725:-1]
bottomdecile
# Out:
#                                School Name  Enrolled population  \
# 725                       Iroquois Jr P.S.                  240
# 726                        St Michael C.S.                  129
# 727                    Givins/Shaw Jr P.S.                  194
# 728                       Subway Academy I                   21
# 729                            Ernest P.S.                   69
# ..                                     ...                  ...
# 800                 Native Learning Centre                   15
# 801  Monsignor Fraser College - St. Martin                   16
# 802                       Rosedale Jr P.S.                  151
# 803                       Montrose Jr P.S.                  112
# 804                      Kimberley Jr P.S.                  160
#
#      DTP coverage rate (%)  MMR coverage rate (%)        Lat        Lng  freq  \
# 725                   99.2                   99.2  43.802680 -79.269441     7
# 726                   82.9                   90.7  43.647869 -79.369620    65
# 727                   92.8                   93.3  43.646408 -79.417584    51
# 728                   71.4                   81.0  43.679140 -79.336636    19
# 729                   95.7                   91.3  43.791415 -79.337383    17
# ..                     ...                    ...        ...        ...   ...
# 800                   66.7                   86.7  43.663608 -79.379178    67
# 801                   62.5                  100.0  43.667175 -79.364426    67
# 802                   98.7                   98.7  43.677656 -79.381686    53
# 803                   99.1                   98.2  43.658682 -79.418844    53
# 804                  100.0                  100.0  43.682620 -79.299128    13
#
#      Average vaccine coverage rate (%)  Average vaccine noncoverage rate (%)  \
# 725                              99.20                                  0.80
# 726                              86.80                                 13.20
# 727                              93.05                                  6.95
# 728                              76.20                                 23.80
# 729                              93.50                                  6.50
# ..                                 ...                                   ...
# 800                              76.70                                 23.30
# 801                              81.25                                 18.75
# 802                              98.70                                  1.30
# 803                              98.65                                  1.35
# 804                             100.00                                  0.00
#
#      Average vaccine noncoverage ratio  Nonvaccinated students  \
# 725                             0.0080                    1.92
# 726                             0.1320                   17.03
# 727                             0.0695                   13.48
# 728                             0.2380                    5.00
# 729                             0.0650                    4.49
# ..                                 ...                     ...
# 800                             0.2330                    3.49
# 801                             0.1875                    3.00
# 802                             0.0130                    1.96
# 803                             0.0135                    1.51
# 804                             0.0000                    0.00
#
#      Nonvaccinated students/clinic
# 725                           0.27
# 726                           0.26
# 727                           0.26
# 728                           0.26
# 729                           0.26
# ..                             ...
# 800                           0.05
# 801                           0.04
# 802                           0.04
# 803                           0.03
# 804                           0.00
#
# [80 rows x 12 columns]

# %%
# generating map of Toronto with top 10% of schools with the highest rate of nonvaccinated students/clinic
map_deciles = folium.Map(location=[latitude, longitude], zoom_start=10.7)

# adding markers to map
for lat, lng, school, non, nsc in zip(topdecile['Lat'], topdecile['Lng'], topdecile['School Name'], topdecile['Nonvaccinated students'], topdecile['Nonvaccinated students/clinic']):
    label = ("{}, Nonvaccinated students: {}, Nonvaccinated students/clinic: {}").format(school, non, nsc)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=6,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#40e3f5',
        fill_opacity=0.7,
        parse_html=False).add_to(map_deciles)
    
for lat, lng, school, non, nsc in zip(bottomdecile['Lat'], bottomdecile['Lng'], bottomdecile['School Name'], bottomdecile['Nonvaccinated students'], bottomdecile['Nonvaccinated students/clinic']):
    label = ("{}, Nonvaccinated students: {}, Nonvaccinated students/clinic: {}").format(school, non, nsc)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=6,
        popup=label,
        color='red',
        fill=True,
        fill_color='#fa7b0c',
        fill_opacity=0.7,
        parse_html=False).add_to(map_deciles)
    
# generating map    
map_deciles
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### Figure 3. Map representing the population of nonvaccinated students and nonvaccinated students/clinic for each school in Toronto. The blue markers represent the top 10% of schools in Toronto in terms of highest nonvaccinated student/clinic rate, and the red markers represent the bottom 10% of schools. From an investor standpoint: the blue markers would be ideal locations to open a medical clinic, and the red markers would be non-ideal locations with heavy competition.

# %%
# dropping all other columns to show only simplified information in dataframe

df.drop(df.columns[1:10], axis = 1, inplace = True)

df
# Out:
#                                School Name  Nonvaccinated students  \
# 0    Monsignor Percy Johnson Catholic H.S.                   95.47
# 1               Josyf Cardinal Slipyj C.S.                   60.04
# 2              St. Basil The Great College                  117.62
# 3       St. Mother Teresa Catholic Academy                   54.52
# 4                         St Benedict C.S.                   52.54
# ..                                     ...                     ...
# 801  Monsignor Fraser College - St. Martin                    3.00
# 802                       Rosedale Jr P.S.                    1.96
# 803                       Montrose Jr P.S.                    1.51
# 804                      Kimberley Jr P.S.                    0.00
# 805                 Anson S Taylor Jr P.S.                    0.00
#
#      Nonvaccinated students/clinic
# 0                            95.47
# 1                            60.04
# 2                            58.81
# 3                            54.52
# 4                            52.54
# ..                             ...
# 801                           0.04
# 802                           0.04
# 803                           0.03
# 804                           0.00
# 805                           0.00
#
# [806 rows x 3 columns]

# %% [markdown]
# ## Data Insights:
#
# From this analysis we can see the top areas of interest to a possible investor looking to open a medical clinic in the city of Toronto. A noteworthy argument against this analysis however is that this analysis makes the assumption that there is a strong correlation between vaccination rates and disease prevalence in the local area. In reality there may only be occasional outbreaks. Furthermore, the Foursquare venue data is not entirely accurate and may be making our data dirty to some degree. For example, many Goodlife Fitness gyms have been miscategorized as medical clinics, which have been removed, but other venues may also be miscategorized. The results may also be skewed because of a really high number of medical clinics per school in the downtown area.
#
# That being said though, this analysis does discover some interesting trends. It can be noted that the worst schools in terms of high numbers of nonvaccinated students/clinic tend to be high population schools in some of the poorer areas of the city. Furthermore the data also shows that the schools with the lowest rates of nonvaccinated students/clinic tend to be low population schools, possibly alternative and/or private schools with stringent vaccination requirements. This is supported by the fact that many of these low population schools are in downtown, which should normally have higher populations. This data thus suggests a possible correlation between vaccination rates and income.
